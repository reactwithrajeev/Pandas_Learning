# %% [markdown]
# # Data Manipulation & Cleaning With Pandas

# %%
import pandas as pd
import numpy as np

# %%
Insurance_Data = pd.read_csv("C:\Data Analytics\Python\Pandas\insurance.csv")
Insurance_Data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
Insurance_Data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# # Add and Remove Columns

# %%
Insurance_Data['Family_Count']= Insurance_Data['children']+ 1

# %%
Insurance_Data['Family_Count']
# Out:
# 0       1
# 1       2
# 2       4
# 3       1
# 4       1
#        ..
# 1333    4
# 1334    1
# 1335    1
# 1336    1
# 1337    1
# Name: Family_Count, Length: 1338, dtype: int64

# %%
Insurance_Data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses  Family_Count
# 0   19  female  27.9         0    yes  southwest  16884.92             1
# 1   18    male  33.8         1     no  southeast   1725.55             2
# 2   28    male  33.0         3     no  southeast   4449.46             4
# 3   33    male  22.7         0     no  northwest  21984.47             1
# 4   32    male  28.9         0     no  northwest   3866.86             1

# %%
Insurance_Data['Avg_exp_per_head']= Insurance_Data['expenses']/Insurance_Data['Family_Count']

# %%
Insurance_Data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses  Family_Count  \
# 0   19  female  27.9         0    yes  southwest  16884.92             1
# 1   18    male  33.8         1     no  southeast   1725.55             2
# 2   28    male  33.0         3     no  southeast   4449.46             4
# 3   33    male  22.7         0     no  northwest  21984.47             1
# 4   32    male  28.9         0     no  northwest   3866.86             1
#
#    Avg_exp_per_head
# 0         16884.920
# 1           862.775
# 2          1112.365
# 3         21984.470
# 4          3866.860

# %% [markdown]
# # REmove Columns

# %%
without_children = Insurance_Data.drop('children', axis=1)
without_children.head()
# Out:
#    age     sex   bmi smoker     region  expenses  Family_Count  \
# 0   19  female  27.9    yes  southwest  16884.92             1
# 1   18    male  33.8     no  southeast   1725.55             2
# 2   28    male  33.0     no  southeast   4449.46             4
# 3   33    male  22.7     no  northwest  21984.47             1
# 4   32    male  28.9     no  northwest   3866.86             1
#
#    Avg_exp_per_head
# 0         16884.920
# 1           862.775
# 2          1112.365
# 3         21984.470
# 4          3866.860

# %%
Insurance_Data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses  Family_Count  \
# 0   19  female  27.9         0    yes  southwest  16884.92             1
# 1   18    male  33.8         1     no  southeast   1725.55             2
# 2   28    male  33.0         3     no  southeast   4449.46             4
# 3   33    male  22.7         0     no  northwest  21984.47             1
# 4   32    male  28.9         0     no  northwest   3866.86             1
#
#    Avg_exp_per_head
# 0         16884.920
# 1           862.775
# 2          1112.365
# 3         21984.470
# 4          3866.860

# %%
without_children.drop('bmi',axis=1, inplace=True)

# %%
without_children.head()
# Out:
#    age     sex smoker     region  expenses  Family_Count  Avg_exp_per_head
# 0   19  female    yes  southwest  16884.92             1         16884.920
# 1   18    male     no  southeast   1725.55             2           862.775
# 2   28    male     no  southeast   4449.46             4          1112.365
# 3   33    male     no  northwest  21984.47             1         21984.470
# 4   32    male     no  northwest   3866.86             1          3866.860

# %%
Insurance_Data.sort_values(['age','children'], ascending=[False,False]).head(10)
# Out:
#       age     sex   bmi  children smoker     region  expenses  Family_Count  \
# 378    64  female  30.1         3     no  northwest  16455.71             4
# 603    64  female  39.1         3     no  southeast  16085.13             4
# 94     64  female  31.3         2    yes  southwest  47291.06             3
# 398    64    male  25.6         2     no  southwest  14988.43             3
# 825    64  female  31.8         2     no  northeast  16069.08             3
# 1241   64    male  37.0         2    yes  southeast  49577.66             3
# 62     64    male  24.7         1     no  northwest  30166.62             2
# 328    64  female  33.8         1    yes  southwest  47928.03             2
# 418    64    male  39.2         1     no  southeast  14418.28             2
# 199    64  female  39.3         0     no  northeast  14901.52             1
#
#       Avg_exp_per_head
# 378        4113.927500
# 603        4021.282500
# 94        15763.686667
# 398        4996.143333
# ...

# %% [markdown]
# # Filtering & Sorting Dataset

# %%
Insurance_Data.sort_index().head(15)
# Out:
#     age     sex   bmi  children smoker     region  expenses  Family_Count  \
# 0    19  female  27.9         0    yes  southwest  16884.92             1
# 1    18    male  33.8         1     no  southeast   1725.55             2
# 2    28    male  33.0         3     no  southeast   4449.46             4
# 3    33    male  22.7         0     no  northwest  21984.47             1
# 4    32    male  28.9         0     no  northwest   3866.86             1
# 5    31  female  25.7         0     no  southeast   3756.62             1
# 6    46  female  33.4         1     no  southeast   8240.59             2
# 7    37  female  27.7         3     no  northwest   7281.51             4
# 8    37    male  29.8         2     no  northeast   6406.41             3
# 9    60  female  25.8         0     no  northwest  28923.14             1
# 10   25    male  26.2         0     no  northeast   2721.32             1
# 11   62  female  26.3         0    yes  southeast  27808.73             1
# ...

# %%
Insurance_Data['age'].min(), Insurance_Data['age'].max()
# Out:
# (18, 64)

# %%
grouped_df = Insurance_Data.groupby('age')
grouped_df['Avg_exp_per_head'].mean()
# Out:
# age
# 18     5844.538594
# 19     8318.573725
# 20     6715.886092
# 21     2721.650696
# 22     6206.272262
# 23     7159.838393
# 24     9612.090244
# 25     5525.646417
# 26     3107.508494
# 27     8868.835536
# 28     5352.318899
# 29     6020.556877
# 30     6419.847130
# 31     4805.285031
# 32     4671.187923
# 33     8531.368487
# 34     6374.848686
# 35     4687.920160
# 36     6548.692847
# 37    10310.551667
# 38     3702.388400
# 39     4840.713860
# 40     5215.031901
# 41     4485.472963
# 42     7784.285556
# 43     9674.311667
# 44     9119.037407
# 45     8952.840259
# 46     7166.901236
# 47     9235.692718
# 48     8602.939138
# 49     6699.034030
# 50     8678.248667
# 51     8618.830632
# 52     9172.137701
# 53     9324.043244
# 54    10141.672024
# 55    11437.414808
# 56    10936.468987
# 57    12748.351603
# 58    11750.175933
# 59    10932.092333
# 60    19448.705761
# 61    15297.283014
# 62    14677.168804
# 63    16390.902138
# 64    16187.065076
# ...

# %%
grouped_df['Avg_exp_per_head'].agg(['mean','count','std'])
# Out:
#              mean  count           std
# age
# 18    5844.538594     69   9520.074546
# 19    8318.573725     68  11855.634963
# 20    6715.886092     29   8516.566620
# 21    2721.650696     28   3251.111162
# 22    6206.272262     28   9623.579993
# 23    7159.838393     28   8245.868070
# 24    9612.090244     28  12412.526039
# 25    5525.646417     28   7361.834999
# 26    3107.508494     28   3451.487700
# 27    8868.835536     28  11408.063733
# 28    5352.318899     28   8075.055315
# 29    6020.556877     27   7627.704122
# 30    6419.847130     27   9333.992576
# 31    4805.285031     27   6341.799011
# 32    4671.187923     26   4730.147506
# 33    8531.368487     26  12806.837158
# 34    6374.848686     26   7772.206694
# 35    4687.920160     25   5108.445761
# 36    6548.692847     25   7727.272091
# 37   10310.551667     25  11165.589091
# 38    3702.388400     25   3128.799963
# 39    4840.713860     25   4602.002146
# 40    5215.031901     27   4484.639465
# ...

# %%
grp_df = Insurance_Data.groupby('sex')
grp_df['age'].mean()
# Out:
# sex
# female    39.503021
# male      38.917160
# Name: age, dtype: float64
